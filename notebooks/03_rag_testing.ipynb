# %%
"""
RAG SYSTEM - Document Analysis Integration
Analyze PDFs (annual reports, financial statements) with AI
"""

import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_community.utilities import SerpAPIWrapper
from langchain_community.document_loaders import PyPDFLoader
from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from typing import List, Dict
import json

# Load environment
load_dotenv()

# Initialize
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

# Use HuggingFace embeddings (already installed!)
print("⏳ Loading embedding model...")
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

search = SerpAPIWrapper()

# Create data directory for PDFs
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/vector_db", exist_ok=True)

print("✅ RAG System Initialized!")
print("📁 PDF Directory: data/raw/")
print("💾 Vector DB: data/vector_db/")
print("🔧 Embedding Model: sentence-transformers/all-MiniLM-L6-v2")
print("📦 Using Your Installed Libraries:")
print(f"   - torch: 2.9.1")
print(f"   - sentence-transformers: 5.1.2")
print(f"   - transformers: 4.57.1")
# Out:
# ⏳ Loading embedding model...
# ✅ RAG System Initialized!
# 📁 PDF Directory: data/raw/
# 💾 Vector DB: data/vector_db/
# 🔧 Embedding Model: sentence-transformers/all-MiniLM-L6-v2
# 📦 Using Your Installed Libraries:
#    - torch: 2.9.1
#    - sentence-transformers: 5.1.2
#    - transformers: 4.57.1

# %%
class RAGDocumentProcessor:
    """Process and index PDF documents"""
    
    def __init__(self, vector_db_path="data/vector_db"):
        self.vector_db_path = vector_db_path
        # Use the HuggingFace embeddings from Cell 1
        self.embeddings = embeddings  # ← This uses the global embeddings variable
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            chunk_overlap=200
        )
        self.vectorstore = None
        
    def load_pdf(self, pdf_path: str) -> List:
        """Load and split PDF into chunks"""
        print(f"📄 Loading PDF: {pdf_path}")
        
        loader = PyPDFLoader(pdf_path)
        documents = loader.load()
        
        print(f"✅ Loaded {len(documents)} pages")
        
        # Split into chunks
        chunks = self.text_splitter.split_documents(documents)
        print(f"✅ Created {len(chunks)} text chunks")
        
        return chunks
    
    def create_vectorstore(self, documents: List, collection_name: str = "financial_docs"):
        """Create vector database from documents"""
        print(f"💾 Creating vector database: {collection_name}")
        
        self.vectorstore = Chroma.from_documents(
            documents=documents,
            embedding=self.embeddings,  # Uses HuggingFace embeddings
            collection_name=collection_name,
            persist_directory=self.vector_db_path
        )
        
        print("✅ Vector database created!")
        return self.vectorstore
    
    def load_vectorstore(self, collection_name: str = "financial_docs"):
        """Load existing vector database"""
        print(f"📂 Loading vector database: {collection_name}")
        
        self.vectorstore = Chroma(
            collection_name=collection_name,
            embedding_function=self.embeddings,  # Uses HuggingFace embeddings
            persist_directory=self.vector_db_path
        )
        
        print("✅ Vector database loaded!")
        return self.vectorstore
    
    def query_documents(self, query: str, k: int = 5) -> List[str]:
        """Query documents and return relevant chunks"""
        if not self.vectorstore:
            print("⚠️ No vector database loaded!")
            return []
        
        results = self.vectorstore.similarity_search(query, k=k)
        return [doc.page_content for doc in results]

# Initialize processor with HuggingFace embeddings
rag_processor = RAGDocumentProcessor()

print("✅ RAG Document Processor Ready!")
print("🔧 Using HuggingFace Embeddings (from Cell 1)")
# Out:
# ✅ RAG Document Processor Ready!
# 🔧 Using HuggingFace Embeddings (from Cell 1)

# %%
def research_with_rag(query: str, pdf_path: str = None, use_existing_db: bool = False):
    """
    Enhanced research combining PDF analysis with web search
    """
    
    print("\n" + "="*70)
    print("🔍 ENHANCED RAG-POWERED RESEARCH")
    print("="*70)
    print(f"Query: {query}\n")
    
    # Step 1: Process PDF if provided
    pdf_insights = ""
    if pdf_path and os.path.exists(pdf_path):
        print("📄 Processing PDF document...")
        
        # Load and index PDF
        chunks = rag_processor.load_pdf(pdf_path)
        rag_processor.create_vectorstore(chunks, collection_name="current_research")
        
        # Query PDF for relevant info
        print(f"🔍 Extracting insights from PDF...")
        relevant_chunks = rag_processor.query_documents(query, k=5)
        
        pdf_insights = "\n\n".join(relevant_chunks)
        print(f"✅ Extracted {len(relevant_chunks)} relevant sections from PDF\n")
        
    elif use_existing_db:
        print("📂 Using existing document database...")
        rag_processor.load_vectorstore("current_research")
        relevant_chunks = rag_processor.query_documents(query, k=5)
        pdf_insights = "\n\n".join(relevant_chunks)
        print(f"✅ Retrieved {len(relevant_chunks)} relevant sections\n")
    
    # Step 2: Web research
    print("🌐 Conducting web research...")
    web_results = search.run(f"{query} 2025 2026")
    print("✅ Web research complete\n")
    
    # Step 3: Generate enhanced report
    print("📝 Generating comprehensive report...")
    
    report_prompt = f"""You are a financial analyst with access to both company documents and market research.

Query: {query}

INTERNAL DOCUMENT DATA:
{pdf_insights[:4000] if pdf_insights else "No internal documents provided."}

WEB RESEARCH DATA:
{web_results[:2000]}

Generate a comprehensive analysis (1000-1500 words) that:
1. EXECUTIVE SUMMARY
2. KEY FINDINGS FROM INTERNAL DOCUMENTS (if available)
   - Financial metrics
   - Strategic initiatives
   - Performance indicators
3. MARKET CONTEXT (from web research)
   - Industry trends
   - Competitive landscape
4. SYNTHESIS & INSIGHTS
   - Combine document data with market context
   - Identify opportunities and risks
5. RECOMMENDATIONS

Use specific numbers, dates, and facts. Clearly cite whether information comes from internal documents or market research.
"""
    
    response = llm.invoke(report_prompt)
    final_report = response.content
    
    # Save report
    os.makedirs("outputs/reports", exist_ok=True)
    from datetime import datetime
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    filename = f"outputs/reports/{timestamp}_RAG_Enhanced_{query[:40].replace(' ', '_')}.md"
    
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(f"# RAG-Enhanced Financial Analysis\n\n")
        f.write(f"**Query:** {query}\n\n")
        f.write(f"**PDF Analyzed:** {'Yes' if pdf_insights else 'No'}\n\n")
        f.write(f"**Date:** {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
        f.write("---\n\n")
        f.write(final_report)
    
    print(f"\n💾 Report saved: {filename}")
    print("\n🎉 RAG-ENHANCED RESEARCH COMPLETE!")
    
    return final_report, filename

print("✅ RAG-Enhanced Research Function Ready!")
# Out:
# ✅ RAG-Enhanced Research Function Ready!

# %%
def process_multiple_pdfs(pdf_directory: str = "data/raw"):
    """
    Process all PDFs in a directory and create unified vector database
    """
    
    print("\n" + "="*70)
    print("📚 BATCH PDF PROCESSING")
    print("="*70)
    
    # Find all PDFs
    pdf_files = [f for f in os.listdir(pdf_directory) if f.endswith('.pdf')]
    
    if not pdf_files:
        print(f"⚠️ No PDF files found in {pdf_directory}")
        return
    
    print(f"Found {len(pdf_files)} PDF files:\n")
    for i, pdf in enumerate(pdf_files, 1):
        print(f"{i}. {pdf}")
    
    # Process all PDFs
    all_chunks = []
    
    for pdf_file in pdf_files:
        pdf_path = os.path.join(pdf_directory, pdf_file)
        print(f"\n📄 Processing: {pdf_file}")
        
        chunks = rag_processor.load_pdf(pdf_path)
        all_chunks.extend(chunks)
    
    # Create unified vector database
    print(f"\n💾 Creating unified vector database with {len(all_chunks)} chunks...")
    rag_processor.create_vectorstore(all_chunks, collection_name="financial_docs")
    
    print("\n✅ All PDFs processed and indexed!")
    print(f"📊 Total chunks in database: {len(all_chunks)}")

print("✅ Batch Processing Function Ready!")
# Out:
# ✅ Batch Processing Function Ready!

# %%
def query_document_database(query: str, k: int = 5):
    """
    Query the document database directly
    """
    
    print("\n" + "="*70)
    print("🔍 DOCUMENT DATABASE QUERY")
    print("="*70)
    print(f"Query: {query}\n")
    
    # Load database
    rag_processor.load_vectorstore("financial_docs")
    
    # Query
    results = rag_processor.query_documents(query, k=k)
    
    print(f"✅ Found {len(results)} relevant sections:\n")
    
    for i, result in enumerate(results, 1):
        print(f"\n--- Result {i} ---")
        print(result[:300] + "..." if len(result) > 300 else result)
        print()
    
    return results

print("✅ Document Query Interface Ready!")
# Out:
# ✅ Document Query Interface Ready!

# %%
# TEST 1: Research without PDF (web-only)
print("\n" + "="*70)
print("TEST 1: WEB-ONLY RESEARCH")
print("="*70)

report1, file1 = research_with_rag(
    query="Infosys Q3 FY26 financial results and profit margins",
    pdf_path=None
)

print("\n📄 Report Preview:")
print(report1[:500] + "...")
# Out:
# ======================================================================
# TEST 1: WEB-ONLY RESEARCH
# ======================================================================
#
# ======================================================================
# 🔍 ENHANCED RAG-POWERED RESEARCH
# ======================================================================
# Query: Infosys Q3 FY26 financial results and profit margins
#
# 🌐 Conducting web research...
# ✅ Web research complete
#
# 📝 Generating comprehensive report...
#
# 💾 Report saved: outputs/reports/20260202_181314_RAG_Enhanced_Infosys_Q3_FY26_financial_results_and_pr.md
#
# 🎉 RAG-ENHANCED RESEARCH COMPLETE!
#
# 📄 Report Preview:
# # Infosys Q3 FY26 Financial Results and Profit Margins Analysis
#
# ## EXECUTIVE SUMMARY
#
# Infosys, a leading global technology services and consulting company, reported its financial results for the third quarter of fiscal year 2026 (Q3 FY26) on January 14, 2026. The company demonstrated resilience in a challenging market environment, with a consolidated revenue of ₹45,479 crore, reflecting a 2.2% increase from the previous quarter and a 9% increase year-on-year. However, the operating profit exper...

# %%
print("\n" + "="*70)
print("📁 HOW TO USE WITH PDFs")
print("="*70)
print("""
To analyze PDF documents:

1. Place your PDF files in: data/raw/
   - Annual reports
   - Financial statements
   - Quarterly results
   - Company presentations

2. For SINGLE PDF analysis:
   report, file = research_with_rag(
       query="Your analysis question",
       pdf_path="data/raw/your_document.pdf"
   )

3. For MULTIPLE PDFs:
   # First, process all PDFs
   process_multiple_pdfs("data/raw")
   
   # Then query
   report, file = research_with_rag(
       query="Your analysis question",
       use_existing_db=True
   )

4. To query documents directly:
   results = query_document_database("Your question")

""")

print("📂 Current PDF directory: data/raw/")
print(f"📊 PDFs found: {len([f for f in os.listdir('data/raw') if f.endswith('.pdf')])}")
# Out:
# ======================================================================
# 📁 HOW TO USE WITH PDFs
# ======================================================================
#
# To analyze PDF documents:
#
# 1. Place your PDF files in: data/raw/
#    - Annual reports
#    - Financial statements
#    - Quarterly results
#    - Company presentations
#
# 2. For SINGLE PDF analysis:
#    report, file = research_with_rag(
#        query="Your analysis question",
#        pdf_path="data/raw/your_document.pdf"
#    )
#
# 3. For MULTIPLE PDFs:
#    # First, process all PDFs
#    process_multiple_pdfs("data/raw")
#
#    # Then query
#    report, file = research_with_rag(
#        query="Your analysis question",
#        use_existing_db=True
#    )
#
# 4. To query documents directly:
#    results = query_document_database("Your question")
#
#
# 📂 Current PDF directory: data/raw/
# 📊 PDFs found: 0

# %%
# If you have PDFs in data/raw/, uncomment and run:

# Example 1: Single PDF
# report, file = research_with_rag(
#     query="What are the revenue trends and profit margins?",
#     pdf_path="data/raw/company_annual_report.pdf"
# )

# Example 2: Multiple PDFs
# process_multiple_pdfs("data/raw")
# report, file = research_with_rag(
#     query="Compare financial performance across companies",
#     use_existing_db=True
# )

# Example 3: Direct document query
# results = query_document_database("Revenue growth Q3 FY26")

print("✅ RAG System Ready!")
print("📁 Add PDFs to data/raw/ and uncomment examples above to test!")
# Out:
# ✅ RAG System Ready!
# 📁 Add PDFs to data/raw/ and uncomment examples above to test!

# %%
# TEST: 400-page Annual Report Analysis
print("\n" + "="*70)
print("📚 TESTING RAG WITH LARGE PDF (400 pages)")
print("="*70)

# Replace with YOUR actual filename
pdf_filename = "annual-report-2024-2025.pdf"  # ← CHANGE THIS!

# Smaller, focused query works best
report, file = research_with_rag(
    query="What are the revenue, profit margins, and key growth strategies for FY 2024-2025?",
    pdf_path=f"data/raw/{pdf_filename}"
)

print("\n" + "="*70)
print("📄 ENHANCED REPORT (PDF + Web Research):")
print("="*70)
print(report)
# Out:
# ======================================================================
# 📚 TESTING RAG WITH LARGE PDF (400 pages)
# ======================================================================
#
# ======================================================================
# 🔍 ENHANCED RAG-POWERED RESEARCH
# ======================================================================
# Query: What are the revenue, profit margins, and key growth strategies for FY 2024-2025?
#
# 📄 Processing PDF document...
# 📄 Loading PDF: data/raw/annual-report-2024-2025.pdf
# ✅ Loaded 336 pages
# ✅ Created 1411 text chunks
# 💾 Creating vector database: current_research
# ✅ Vector database created!
# 🔍 Extracting insights from PDF...
# ✅ Extracted 5 relevant sections from PDF
#
# 🌐 Conducting web research...
# ✅ Web research complete
#
# 📝 Generating comprehensive report...
#
# 💾 Report saved: outputs/reports/20260202_184142_RAG_Enhanced_What_are_the_revenue,_profit_margins,_an.md
#
# 🎉 RAG-ENHANCED RESEARCH COMPLETE!
#
# ======================================================================
# 📄 ENHANCED REPORT (PDF + Web Research):
# ======================================================================
# # Comprehensive Analysis of TCS for FY 2024-2025
#
# ## EXECUTIVE SUMMARY
#
# Tata Consultancy Services (TCS) has demonstrated resilience and adaptability in its financial performance for FY 2024-2025, achieving a revenue growth of 6.0% in FY 2025, despite macroeconomic uncertainties. The company's operating profit margins remain robust, with a slight decline to 24.3% from 24.6% in FY 2024. TCS's strategic focus on operational excellence, cost optimization, and investment in technology modernization has positioned it well for future growth. However, external market pressures and evolving industry dynamics necessitate a proactive approach to sustain profitability and capitalize on emerging opportunities.
#
# ## KEY FINDINGS FROM INTERNAL DOCUMENTS
#
# ### Financial Metrics
#
# - **Revenue**: TCS reported revenue from operations of ₹255,324 crore in FY 2025, reflecting a 6.0% increase from ₹240,893 crore in FY 2024.
# - **Operating Profit**: The operating profit for FY 2025 was ₹62,165 crore, with an operating margin of 24.3%, slightly down from 24.6% in FY 2024.
# - **Profit After Tax**: The profit after tax attributable to shareholders was ₹48,553 crore, representing a year-over-year growth of 4.2%.
# - **Earnings Per Share (EPS)**: The EPS increased to ₹134.19 from ₹127.74 in FY 2024.
#
# ### Strategic Initiatives
#
# TCS has implemented several strategic initiatives aimed at enhancing operational efficiency and fostering growth:
#
# - **Cost Optimization**: The company has focused on operational excellence and cost management to mitigate the impact of wage hikes and infrastructure investments.
# - **Investment in Technology**: TCS is prioritizing technology modernization and vendor consolidation, which are critical for maintaining competitiveness in a rapidly evolving market.
# - **Client Engagement**: The company has emphasized strengthening customer relationships and optimizing sales processes to drive revenue growth.
#
# ### Performance Indicators
#
# - **Growth by Segment**: TCS's revenue growth varied by segment, with notable performance in the Communication, Media, and Technology sector (16.5% growth) and Banking, Financial Services, and Insurance (4.0% growth).
# - **CAGR**: Over the past five years, TCS has recorded a compound annual growth rate (CAGR) of 10.2%, indicating a strong and scalable business model.
#
# ## MARKET CONTEXT
#
# ### Industry Trends
#
# The IT services industry is experiencing significant transformations driven by technological advancements and changing client needs. Key trends include:
#
# - **Digital Transformation**: Companies are increasingly investing in digital solutions to enhance operational efficiency and customer engagement. This trend is expected to accelerate as businesses seek to modernize their operations.
# - **AI and Automation**: The integration of AI technologies is becoming a critical driver of revenue growth for leading firms, as they leverage automation to improve service delivery and reduce costs.
# - **Cost Management**: Organizations are focusing on better cost management and cash flow optimization to navigate economic uncertainties.
#
# ### Competitive Landscape
#
# The competitive landscape for IT services is characterized by:
#
# - **Increased Competition**: Major players are intensifying their efforts to capture market share, leading to pricing pressures and the need for differentiation through innovation.
# - **Emerging Startups**: New entrants focusing on niche technologies, such as AI and cloud computing, are disrupting traditional business models and attracting significant investment.
#
# ## SYNTHESIS & INSIGHTS
#
# Combining insights from internal documents and market research reveals a nuanced picture of TCS's position in the market:
#
# ### Opportunities
#
# 1. **Expansion in High-Growth Segments**: TCS can capitalize on the rapid growth in the Communication, Media, and Technology sector, which has shown a significant increase in demand for IT services.
# 2. **Leveraging AI and Automation**: By investing further in AI and automation technologies, TCS can enhance service delivery and operational efficiency, positioning itself as a leader in digital transformation.
# 3. **Geographic Diversification**: Expanding into emerging markets could provide new revenue streams and reduce dependency on mature markets.
#
# ### Risks
#
# 1. **Macroeconomic Uncertainty**: Ongoing economic challenges could impact client budgets and spending on IT services, leading to potential revenue stagnation.
# 2. **Talent Management**: The rising costs associated with wage hikes and talent retention could pressure profit margins if not managed effectively.
# 3. **Competitive Pressures**: The increasing competition from both established players and new entrants necessitates continuous innovation and differentiation.
#
# ## RECOMMENDATIONS
#
# To navigate the challenges and seize opportunities in the evolving market landscape, TCS should consider the following recommendations:
#
# 1. **Enhance Digital Offerings**: Invest in developing advanced digital solutions and services that cater to the specific needs of clients in high-growth sectors, particularly in AI and automation.
# 2. **Strengthen Client Relationships**: Implement strategies to deepen client engagement and loyalty, focusing on personalized service delivery and value-added solutions.
# 3. **Optimize Cost Structures**: Continue to refine cost management strategies to enhance operational efficiency while ensuring that investments in talent and technology are aligned with long-term growth objectives.
# 4. **Expand Geographically**: Identify and pursue growth opportunities in emerging markets where demand for IT services is on the rise, diversifying revenue sources and reducing reliance on established markets.
# 5. **Monitor Industry Trends**: Stay abreast of industry trends and competitor strategies to proactively adapt to market changes and maintain a competitive edge.
#
# By executing these strategies, TCS can reinforce its market position, drive sustainable growth, and enhance shareholder value in the coming years.
