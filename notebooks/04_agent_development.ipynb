# %%
from langchain_openai import ChatOpenAI
from tavily import TavilyClient
from dotenv import load_dotenv
import os

load_dotenv()

print("✅ All imports successful!")
print(f"✅ OpenAI Key loaded: {os.getenv('OPENAI_API_KEY')[:10]}...")
print(f"✅ Tavily Key loaded: {os.getenv('TAVILY_API_KEY')[:10]}...")
# Out:
# ✅ All imports successful!
# ✅ OpenAI Key loaded: sk-proj-FH...
# ✅ Tavily Key loaded: tvly-dev-j...

# %%
# Test web search
from tavily import TavilyClient
import os

tavily = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))

# Test search
results = tavily.search("Indian IT sector latest news 2026", max_results=3)

for result in results['results']:
    print(f"\n📰 {result['title']}")
    print(f"🔗 {result['url']}")
    print(f"📝 {result['content'][:200]}...")
# Out:
# 📰 Indian IT Sector Set to Outperform Markets in 2026, Says CIO
# 🔗 https://www.whalesbook.com/news/English/tech/Indian-IT-Sector-Set-to-Outperform-Markets-in-2026-Says-CIO/696f3fa4ad039ca929a6f379
# 📝 Indian IT stocks eye 2026 outperformance as AI matures and client spending rebounds. CIO Pankaj Murarka sees a gradual uptick....
#
# 📰 Indian IT Sector To Outperform Markets In 2026, Says Pankaj Murarka
# 🔗 https://www.ndtvprofit.com/markets/indian-it-sector-to-outperform-markets-in-2026-says-pankaj-murarka-10790704
# 📝 Pankaj Murarka expects the Indian IT sector to outperform markets in 2026 · AI maturation is driving improved client sentiment and growth...
#
# 📰 Budget 2026 signals India doubling down on its position as global ...
# 🔗 https://www.moneycontrol.com/news/business/information-technology/budget-2026-signals-india-doubling-down-on-its-position-as-global-tech-services-leader-it-industry-says-13803923.html
# 📝 Budget 2026 signals India doubling down on its position as global tech services leader, IT industry says. As per the new budget, the government...

# %%
# Test OpenAI GPT
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

response = llm.invoke("Explain what a financial research agent does in 2 sentences.")

print("🤖 GPT Response:")
print(response.content)
# Out:
# 🤖 GPT Response:
# A financial research agent conducts in-depth analysis and gathers data on various financial markets, investment opportunities, and economic trends to provide insights and recommendations. They often utilize quantitative and qualitative methods to assess risks and returns, helping clients make informed financial decisions.

# %%
# Step 1: Research Plan Generator
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

def generate_research_plan(query: str) -> dict:
    """Generate a research plan for the query"""
    
    prompt = ChatPromptTemplate.from_template("""
You are a financial research planning assistant for the IT sector.

User Query: {query}

Create a detailed research plan with 5-7 specific search queries that will comprehensively answer this query.
Each search should explore a different aspect.

Format your response as a numbered list of search queries only.

Example format:
1. [First search query]
2. [Second search query]
3. [Third search query]
...
""")
    
    response = llm.invoke(prompt.format_messages(query=query))
    plan = response.content
    
    print("📋 RESEARCH PLAN GENERATED:")
    print("=" * 60)
    print(plan)
    print("=" * 60)
    
    return {
        "query": query,
        "plan": plan,
        "searches_completed": 0,
        "findings": []
    }

# Test it
state = generate_research_plan("Analyze the current state of Indian IT services companies")
# Out:
# 📋 RESEARCH PLAN GENERATED:
# ============================================================
# 1. Current financial performance and revenue growth trends of major Indian IT services companies (e.g., TCS, Infosys, Wipro, HCL Technologies).
# 2. Impact of global economic conditions on the Indian IT services sector in 2023.
# 3. Analysis of emerging technologies and their adoption in Indian IT services (e.g., AI, cloud computing, cybersecurity).
# 4. Competitive landscape and market share analysis of Indian IT services firms compared to global players.
# 5. Recent mergers, acquisitions, and partnerships in the Indian IT services industry and their implications.
# 6. Talent acquisition and workforce trends in Indian IT services companies, including challenges and strategies.
# 7. Regulatory and policy changes affecting the Indian IT services sector in 2023.
# ============================================================

# %%
# Step 2: Execute Research Searches
from tavily import TavilyClient
import os
import time

tavily = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))

def execute_research(state: dict, max_searches: int = 5) -> dict:
    """Execute web searches based on the research plan"""
    
    plan_lines = state['plan'].strip().split('\n')
    search_queries = [line.split('. ', 1)[1] if '. ' in line else line 
                     for line in plan_lines if line.strip() and line[0].isdigit()]
    
    # Limit to max_searches
    search_queries = search_queries[:max_searches]
    
    print(f"\n🔍 EXECUTING {len(search_queries)} RESEARCH SEARCHES...")
    print("=" * 60)
    
    all_findings = []
    
    for i, query in enumerate(search_queries, 1):
        print(f"\n[Search {i}/{len(search_queries)}] {query}")
        print("-" * 60)
        
        try:
            results = tavily.search(query, max_results=2)
            
            for result in results['results']:
                finding = {
                    'search_query': query,
                    'title': result['title'],
                    'url': result['url'],
                    'content': result['content']
                }
                all_findings.append(finding)
                
                print(f"✓ Found: {result['title']}")
                print(f"  URL: {result['url']}")
                print(f"  Preview: {result['content'][:150]}...")
            
            time.sleep(1)  # Be nice to the API
            
        except Exception as e:
            print(f"✗ Error: {e}")
    
    state['findings'] = all_findings
    state['searches_completed'] = len(search_queries)
    
    print("\n" + "=" * 60)
    print(f"✅ RESEARCH COMPLETE: {len(all_findings)} findings gathered")
    
    return state

# Execute the research
state = execute_research(state, max_searches=5)
# Out:
# 🔍 EXECUTING 5 RESEARCH SEARCHES...
# ============================================================
#
# [Search 1/5] Current financial performance and revenue growth trends of major Indian IT services companies (e.g., TCS, Infosys, Wipro, HCL Technologies).
# ------------------------------------------------------------
# ✓ Found: Indian IT Firms Dominate Global IT Services 2026 | Saurav Kumar ...
#   URL: https://www.linkedin.com/posts/saurav-kumar-b72835140_indianit-brandfinance-itservices-activity-7419828482567811072-mmVV
#   Preview: The IT major posted revenue of ₹23,555 crore in Q3, marking a 5.5% year on year increase and a sequential rise of about 4%, even as...
# ✓ Found: Indian top IT firms set for another tepid quarter on weak US demand ...
#   URL: https://finance.yahoo.com/news/indian-top-firms-set-another-051502915.html
#   Preview: Infosys and HCLTech are forecast to report year-on-year revenue growth of ​about 8.1% and 4.6%, respectively, compared with 7.6% and 5.1% in the...
#
# [Search 2/5] Impact of global economic conditions on the Indian IT services sector in 2023.
# ------------------------------------------------------------
# ✓ Found: Impact of Global Recession on Indian IT sector - Wright Research
#   URL: https://www.wrightresearch.in/blog/it-sector-recession/
#   Preview: This often leads to cost-cutting measures such as workforce reductions, salary freezes, and decreased investment in research and development....
# ✓ Found: India's IT sector vulnerable to US, Europe economic shocks - LinkedIn
#   URL: https://www.linkedin.com/posts/analytics-india-magazine_indias-250-billion-it-services-sector-remains-activity-7379043283873947648-4_qI
#   Preview: “India has just crossed a historic milestone — projected to become the 4th-largest economy in the world by 2025 (in nominal GDP) 🚀” 📊 Key Data & Claim...
#
# [Search 3/5] Analysis of emerging technologies and their adoption in Indian IT services (e.g., AI, cloud computing, cybersecurity).
# ------------------------------------------------------------
# ✓ Found: Emerging Technologies: AI, Cloud, and IT Consulting Landscape
#   URL: https://teleglobals.com/blog/emerging-technologies-ai-cloud-it?srsltid=AfmBOooVsOvUaMCTf9uQIuDqihEQokzkydbRHT37lWd4S3OuvUT_3w0K
#   Preview: Emerging technologies in 2026 include cloud computing trends, Artificial Intelligence (Ai), enterprise cloud solutions, advanced analytics, and...
# ✓ Found: Top Tech Trends for IT & ITeS in India 2026 | Digital Transformation ...
#   URL: https://www.tatatelebusiness.com/articles/top-tech-trends-for-it-ites-industry-india/
#   Preview: The rise of AI, cloud applications and real-time digital services is fuelling massive growth in data centre infrastructure across India. In 2026...
#
# [Search 4/5] Competitive landscape and market share analysis of Indian IT services firms compared to global players.
# ------------------------------------------------------------
# ✓ Found: India IT Services Market Size, Share & 2030 Trends Report
#   URL: https://www.mordorintelligence.com/industry-reports/india-it-services-market
#   Preview: The India IT Services Market Report is Segmented by Service Type (IT Consulting and Implementation, IT Outsourcing, Business Process Outsourcing, and ...
# ✓ Found: Navigating the Landscape of Top Consulting Firms in 2026 - Oreate AI
#   URL: http://oreateai.com/blog/indias-it-powerhouses-navigating-the-landscape-of-top-consulting-firms-in-2026/4fee78b3b0f98497c770b671b471ce70
#   Preview: India's IT sector is booming, driven by GenAI and cloud growth. Top consulting firms are leading this transformation with innovation,...
#
# [Search 5/5] Recent mergers, acquisitions, and partnerships in the Indian IT services industry and their implications.
# ------------------------------------------------------------
# ✓ Found: Indian Information Technology Sector and Its Growth
#   URL: https://www.ibef.org/industry/information-technology-india
#   Preview: India's IT industry is likely to hit the US$ 350 billion mark by 2026 and contribute 10% towards the country's GDP....
# ✓ Found: M&A activity set to remain strong in 2026 after $104 billion domestic ...
#   URL: https://m.economictimes.com/industry/banking/finance/ma-activity-set-to-remain-strong-in-2026-after-104-billion-domestic-consolidation-in-2025/articleshow/126271672.cms
#   Preview: India's mergers and acquisitions pipeline is expected to remain robust in the coming year, building on a strong rebound in dealmaking...
#
# ============================================================
# ✅ RESEARCH COMPLETE: 10 findings gathered

# %%
# Step 3: Generate Research Report
from langchain_core.prompts import ChatPromptTemplate

def generate_report(state: dict) -> str:
    """Synthesize all findings into a comprehensive report"""
    
    # Compile all findings
    findings_text = ""
    for i, finding in enumerate(state['findings'], 1):
        findings_text += f"\n{i}. {finding['title']}\n"
        findings_text += f"   Source: {finding['url']}\n"
        findings_text += f"   {finding['content'][:300]}...\n"
    
    prompt = ChatPromptTemplate.from_template("""
You are a professional financial research analyst specializing in the IT sector.

Original Query: {query}

Research Plan Executed:
{plan}

Findings from {num_findings} sources:
{findings}

Create a comprehensive research report with the following sections:
1. Executive Summary (2-3 sentences)
2. Key Findings (bullet points)
3. Financial Performance Analysis
4. Market Trends & Outlook
5. Risks & Challenges
6. Conclusion

Be specific, cite key metrics, and provide actionable insights.
""")
    
    print("\n📝 GENERATING COMPREHENSIVE REPORT...")
    print("=" * 60)
    
    response = llm.invoke(prompt.format_messages(
        query=state['query'],
        plan=state['plan'],
        num_findings=len(state['findings']),
        findings=findings_text
    ))
    
    report = response.content
    
    print("\n" + "=" * 60)
    print("📊 RESEARCH REPORT")
    print("=" * 60)
    print(report)
    print("=" * 60)
    
    return report

# Generate the report
report = generate_report(state)
# Out:
# 📝 GENERATING COMPREHENSIVE REPORT...
# ============================================================
#
# ============================================================
# 📊 RESEARCH REPORT
# ============================================================
# # Research Report: Current State of Indian IT Services Companies
#
# ## Executive Summary
# The Indian IT services sector is experiencing moderate growth amid global economic uncertainties, particularly in the US and Europe. Major players like TCS, Infosys, and HCL Technologies are adapting to changing market dynamics, focusing on emerging technologies such as AI and cloud computing to drive future growth. However, challenges such as talent acquisition and regulatory changes pose risks to sustained performance.
#
# ## Key Findings
# - **Revenue Growth**: TCS reported a 5.5% year-on-year revenue increase in Q3, while Infosys and HCLTech are projected to grow by 8.1% and 4.6%, respectively.
# - **Global Economic Impact**: The Indian IT sector remains vulnerable to economic shocks in the US and Europe, leading to potential cost-cutting measures.
# - **Emerging Technologies**: Significant investments are being made in AI, cloud computing, and cybersecurity, with a projected market size of $350 billion by 2026.
# - **M&A Activity**: The Indian IT services sector is witnessing robust M&A activity, with a strong pipeline expected to continue into 2026.
# - **Talent Acquisition Challenges**: Companies face difficulties in attracting and retaining skilled talent, necessitating innovative workforce strategies.
#
# ## Financial Performance Analysis
# - **TCS**: Reported revenue of ₹23,555 crore in Q3, marking a 5.5% year-on-year increase and a sequential rise of 4%.
# - **Infosys**: Expected to report a year-on-year revenue growth of 8.1%, down from previous quarters, indicating a slowdown in demand.
# - **HCL Technologies**: Forecasted growth of 4.6%, reflecting a similar trend of deceleration in revenue growth compared to earlier periods.
# - **Overall Sector Growth**: The Indian IT services market is projected to reach $350 billion by 2026, contributing approximately 10% to India's GDP.
#
# ## Market Trends & Outlook
# - **Emerging Technologies**: The adoption of AI and cloud computing is driving growth, with companies investing heavily in data center infrastructure and advanced analytics.
# - **Consulting Services**: The demand for IT consulting and implementation services is on the rise, as businesses seek to leverage technology for digital transformation.
# - **M&A Activity**: The sector is expected to see continued consolidation, with a strong pipeline of mergers and acquisitions anticipated, building on the $104 billion in domestic consolidation recorded in 2025.
#
# ## Risks & Challenges
# - **Global Economic Vulnerability**: The Indian IT sector is highly dependent on the US and European markets, making it susceptible to economic downturns and demand fluctuations.
# - **Talent Shortages**: The competition for skilled IT professionals is intensifying, leading to increased recruitment costs and potential project delays.
# - **Regulatory Changes**: New policies and regulations could impact operational efficiencies and cost structures, necessitating agile responses from companies.
#
# ## Conclusion
# The Indian IT services sector is navigating a complex landscape characterized by moderate growth, emerging technological trends, and significant challenges. Companies must focus on innovation, talent retention, and strategic partnerships to capitalize on growth opportunities while mitigating risks associated with global economic conditions. The outlook remains cautiously optimistic, with the potential for substantial growth driven by advancements in technology and a robust M&A environment.
# ============================================================

# %%
# Advanced Feature 1: Save Reports to Files
from datetime import datetime
from pathlib import Path
import os

def save_report(report: str, query: str, format: str = "md") -> str:
    """Save research report to file"""
    
    # Create outputs directory if it doesn't exist
    output_dir = Path("outputs/reports")
    output_dir.mkdir(parents=True, exist_ok=True)
    
    # Generate filename
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    safe_query = query[:50].replace(" ", "_").replace("/", "-")
    filename = f"{timestamp}_{safe_query}.{format}"
    filepath = output_dir / filename
    
    # Save report
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(f"# Research Report\n")
        f.write(f"**Query:** {query}\n")
        f.write(f"**Generated:** {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write(f"**Sources:** {state['searches_completed']} searches, {len(state['findings'])} findings\n\n")
        f.write("---\n\n")
        f.write(report)
    
    print(f"\n💾 Report saved to: {filepath}")
    return str(filepath)

# Save the report we just generated
filepath = save_report(report, state['query'])
# Out:
# 💾 Report saved to: outputs\reports\20260202_170517_Analyze_the_current_state_of_Indian_IT_services_co.md

# %%
# Advanced Feature 2: Intelligent Sector Router
from langchain_core.prompts import ChatPromptTemplate

def detect_sector(query: str) -> str:
    """Automatically detect which sector the query belongs to"""
    
    prompt = ChatPromptTemplate.from_template("""
You are a financial sector classification expert.

Analyze this query and determine which sector it belongs to:
Query: {query}

Available sectors:
- IT: Information Technology, software, tech services, SaaS, cloud computing
- PHARMA: Pharmaceutical, healthcare, biotech, drug development, medical devices
- GENERAL: If it doesn't clearly fit IT or PHARMA

Respond with ONLY one word: IT, PHARMA, or GENERAL
""")
    
    response = llm.invoke(prompt.format_messages(query=query))
    sector = response.content.strip().upper()
    
    print(f"🎯 SECTOR DETECTED: {sector}")
    return sector

# Test it
test_queries = [
    "Analyze Infosys financial performance",
    "Research Sun Pharma drug pipeline",
    "What are emerging trends in biosimilars?",
    "TCS vs Wipro comparison"
]

print("Testing Sector Detection:")
print("=" * 60)
for q in test_queries:
    print(f"\nQuery: {q}")
    sector = detect_sector(q)
    print("-" * 60)
# Out:
# Testing Sector Detection:
# ============================================================
#
# Query: Analyze Infosys financial performance
# 🎯 SECTOR DETECTED: IT
# ------------------------------------------------------------
#
# Query: Research Sun Pharma drug pipeline
# 🎯 SECTOR DETECTED: PHARMA
# ------------------------------------------------------------
#
# Query: What are emerging trends in biosimilars?
# 🎯 SECTOR DETECTED: PHARMA
# ------------------------------------------------------------
#
# Query: TCS vs Wipro comparison
# 🎯 SECTOR DETECTED: IT
# ------------------------------------------------------------

# %%
# Advanced Feature 3: Deep Iterative Research with Adaptive Queries
def deep_research(state: dict, max_iterations: int = 10) -> dict:
    """
    Advanced research that adapts based on findings.
    Each iteration generates new questions based on previous results.
    """
    
    print(f"\n🔬 STARTING DEEP RESEARCH (up to {max_iterations} iterations)")
    print("=" * 60)
    
    all_findings = []
    iteration = 0
    
    # Initial searches from plan
    plan_lines = state['plan'].strip().split('\n')
    initial_queries = [line.split('. ', 1)[1] if '. ' in line else line 
                       for line in plan_lines if line.strip() and line[0].isdigit()]
    
    search_queue = initial_queries[:5]  # Start with first 5
    searched_queries = set()
    
    while search_queue and iteration < max_iterations:
        iteration += 1
        current_query = search_queue.pop(0)
        
        if current_query in searched_queries:
            continue
            
        searched_queries.add(current_query)
        
        print(f"\n[Iteration {iteration}] 🔍 {current_query}")
        print("-" * 60)
        
        try:
            results = tavily.search(current_query, max_results=2)
            
            iteration_findings = []
            for result in results['results']:
                finding = {
                    'iteration': iteration,
                    'search_query': current_query,
                    'title': result['title'],
                    'url': result['url'],
                    'content': result['content']
                }
                all_findings.append(finding)
                iteration_findings.append(finding)
                
                print(f"  ✓ {result['title'][:80]}...")
            
            # Generate follow-up questions based on findings
            if iteration < max_iterations - 2 and iteration_findings:
                followup = generate_followup_questions(current_query, iteration_findings)
                if followup:
                    search_queue.extend(followup[:2])  # Add top 2 follow-ups
                    print(f"  💡 Generated {len(followup)} follow-up queries")
            
            time.sleep(1)
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
    
    state['findings'] = all_findings
    state['searches_completed'] = len(searched_queries)
    
    print("\n" + "=" * 60)
    print(f"✅ DEEP RESEARCH COMPLETE:")
    print(f"   • {iteration} iterations")
    print(f"   • {len(all_findings)} total findings")
    print(f"   • {len(searched_queries)} unique searches")
    print("=" * 60)
    
    return state

def generate_followup_questions(original_query: str, findings: list) -> list:
    """Generate intelligent follow-up questions based on findings"""
    
    findings_summary = "\n".join([f"- {f['title']}: {f['content'][:150]}" 
                                  for f in findings[:3]])
    
    prompt = ChatPromptTemplate.from_template("""
Based on this search query and results, generate 2 specific follow-up questions to deepen the research.

Original Query: {query}

Findings:
{findings}

Generate 2 specific, focused follow-up questions that dig deeper into interesting aspects mentioned in the findings.
Return only the questions, one per line, no numbering.
""")
    
    try:
        response = llm.invoke(prompt.format_messages(
            query=original_query,
            findings=findings_summary
        ))
        
        questions = [q.strip() for q in response.content.strip().split('\n') 
                    if q.strip() and not q.strip()[0].isdigit()]
        return questions[:2]
    except:
        return []

print("✅ Deep Research System Ready!")
print("This will perform 10+ iterative searches with adaptive follow-ups.")
# Out:
# ✅ Deep Research System Ready!
# This will perform 10+ iterative searches with adaptive follow-ups.

# %%
# Advanced Feature 4: User Approval Before Execution
def research_with_approval(query: str):
    """Complete research flow with user approval step"""
    
    print("\n" + "=" * 60)
    print("🎯 FINANCIAL RESEARCH AGENT")
    print("=" * 60)
    
    # Step 1: Detect sector
    sector = detect_sector(query)
    print(f"\n📊 Sector: {sector}")
    
    # Step 2: Generate plan
    state = generate_research_plan(query)
    
    # Step 3: Show plan and ask for approval
    print("\n⏸️  WAITING FOR APPROVAL")
    print("=" * 60)
    print("Review the research plan above.")
    print("\nOptions:")
    print("  1. Execute research (type 'yes' or 'y')")
    print("  2. Modify plan (type 'modify')")
    print("  3. Cancel (type 'no' or 'n')")
    
    # For notebook, we'll auto-proceed (in production, use input())
    approval = "yes"  # Change to input("Your choice: ") for interactive
    
    if approval.lower() in ['yes', 'y']:
        print("\n✅ APPROVED - Starting research...\n")
        
        # Step 4: Execute deep research
        state = deep_research(state, max_iterations=10)
        
        # Step 5: Generate report
        report = generate_report(state)
        
        # Step 6: Save report
        filepath = save_report(report, query)
        
        print(f"\n🎉 RESEARCH COMPLETE!")
        print(f"   Report saved: {filepath}")
        
        return state, report
    else:
        print("\n❌ Research cancelled")
        return None, None

print("✅ Approval Flow System Ready!")
# Out:
# ✅ Approval Flow System Ready!

# %%
# TEST THE COMPLETE ADVANCED SYSTEM
test_query = "Analyze Indian IT sector performance and AI adoption trends 2026"

state, report = research_with_approval(test_query)
# Out:
# ============================================================
# 🎯 FINANCIAL RESEARCH AGENT
# ============================================================
# 🎯 SECTOR DETECTED: IT
#
# 📊 Sector: IT
# 📋 RESEARCH PLAN GENERATED:
# ============================================================
# 1. Current performance metrics of the Indian IT sector in 2026: revenue growth, market share, and key players.
# 2. Trends in AI adoption within the Indian IT sector: key technologies, use cases, and industry impact.
# 3. Government policies and initiatives supporting AI development in India: analysis of the National AI Strategy and funding programs.
# 4. Comparative analysis of AI adoption in the Indian IT sector versus global trends: benchmarks and best practices.
# 5. Challenges and barriers to AI implementation in the Indian IT sector: workforce skills, infrastructure, and regulatory issues.
# 6. Case studies of successful AI integration in Indian IT companies: lessons learned and future outlook.
# 7. Future projections for the Indian IT sector and AI adoption: expert opinions, market forecasts, and potential disruptions.
# ============================================================
#
# ⏸️  WAITING FOR APPROVAL
# ============================================================
# Review the research plan above.
#
# Options:
#   1. Execute research (type 'yes' or 'y')
#   2. Modify plan (type 'modify')
#   3. Cancel (type 'no' or 'n')
#
# ✅ APPROVED - Starting research...
#
#
# 🔬 STARTING DEEP RESEARCH (up to 10 iterations)
# ============================================================
#
# [Iteration 1] 🔍 Current performance metrics of the Indian IT sector in 2026: revenue growth, market share, and key players.
# ------------------------------------------------------------
#   ✓ Muted revenue growth likely for IT firms in Q3FY26 results, margins ......
#   ✓ Indian Information Technology Sector and Its Growth - IBEF...
#   💡 Generated 2 follow-up queries
#
# [Iteration 2] 🔍 Trends in AI adoption within the Indian IT sector: key technologies, use cases, and industry impact.
# ------------------------------------------------------------
#   ✓ (PDF) Exploring the Impact of AI Integration in the Indian IT Industry...
#   ✓ Top Emerging Digital Trends in India: AI, Cloud & Cybersecurity...
#   💡 Generated 2 follow-up queries
#
# [Iteration 3] 🔍 Government policies and initiatives supporting AI development in India: analysis of the National AI Strategy and funding programs.
# ------------------------------------------------------------
#   ✓ Union Budget 2026: Technology Takes Centre Stage With AI ......
#   ✓ Budget 2026: What AI Needs from India's Finance Ministry...
#   💡 Generated 2 follow-up queries
#
# [Iteration 4] 🔍 Comparative analysis of AI adoption in the Indian IT sector versus global trends: benchmarks and best practices.
# ------------------------------------------------------------
#   ✓ India vs global AI adoption benchmarks - IT Voice...
#   ✓ AI adoption among young Indians: an analysis using a MIMIC model...
#   💡 Generated 2 follow-up queries
#
# [Iteration 5] 🔍 Challenges and barriers to AI implementation in the Indian IT sector: workforce skills, infrastructure, and regulatory issues.
# ------------------------------------------------------------
#   ✓ india ai development challenges - UMU...
#   ✓ India's AI-ready workforce drives growth as CEOs prioritise ......
#   💡 Generated 2 follow-up queries
#
# [Iteration 6] 🔍 What factors are contributing to the muted revenue growth for Tier 1 IT companies in Q3FY26, and how do these factors compare to previous quarters?
# ------------------------------------------------------------
#   ✓ Indian IT Firms Face Muted Q3 Growth, Margins Hold Firm...
#   ✓ Q3FY26 results preview: IT companies' growth likely to remain muted...
#   💡 Generated 2 follow-up queries
#
# [Iteration 7] 🔍 How are emerging technologies and innovations influencing the market share and competitive landscape of key players in the Indian IT sector as it approaches the US$ 350 billion mark?
# ------------------------------------------------------------
#   ✓ Indian IT sector likely to hit $350 billion by 2026, says McKinsey report...
#   ✓ India's 2026 Growth Outlook: Key Sectors Driving Technology-Led ......
#   💡 Generated 2 follow-up queries
#
# [Iteration 8] 🔍 What specific AI technologies are being most widely adopted in the Indian IT sector, and how do they differ across various industries such as banking, retail, and healthcare?
# ------------------------------------------------------------
#   ✓ [PDF] Is India ready for Agentic AI? The AIdea of India: Outlook 2026 - EY...
#   ✓ India Artificial Intelligence - International Trade Administration...
#
# [Iteration 9] 🔍 What are the measurable impacts of AI integration on productivity and efficiency within Indian IT companies, and how do these impacts vary by company size or sector?
# ------------------------------------------------------------
#   ✓ Graph technology & AI trends 2026: India's AI race...
#   ✓ How AI and real-time analytics are transforming India's ......
#
# [Iteration 10] 🔍 What specific initiatives and projects are included in the IndiaAI Mission's five-year outlay of ₹10,371.92 crore, and how do they align with the National AI Strategy?
# ------------------------------------------------------------
#   ✓ Cabinet approves IndiaAI Mission with outlay of ₹10372 crore - Mint...
#   ✓ Transforming India with AI - PIB...
#
# ============================================================
# ✅ DEEP RESEARCH COMPLETE:
#    • 10 iterations
#    • 20 total findings
#    • 10 unique searches
# ============================================================
#
# 📝 GENERATING COMPREHENSIVE REPORT...
# ============================================================
#
# ============================================================
# 📊 RESEARCH REPORT
# ============================================================
# # Research Report: Indian IT Sector Performance and AI Adoption Trends 2026
#
# ## 1. Executive Summary
# The Indian IT sector is projected to reach a market size of approximately USD 350 billion by 2026, driven by robust demand for digital transformation and AI integration across various industries. However, revenue growth for major IT firms is expected to remain muted in the short term, with Q3 FY26 forecasts indicating growth rates between 0.2% and 1.7%. The adoption of AI technologies is accelerating, supported by government initiatives and a growing talent pool, although challenges related to workforce skills and infrastructure persist.
#
# ## 2. Key Findings
# - **Market Size**: The Indian IT sector is expected to hit USD 350 billion by 2026, contributing 10% to the national GDP (Source: IBEF).
# - **Revenue Growth**: Tier 1 IT companies forecasted to experience muted revenue growth of 0.2% to 1.7% in Q3 FY26 (Source: Times of India).
# - **AI Adoption**: Rapid AI integration across sectors such as banking, healthcare, and logistics, with Indian firms outpacing global benchmarks in deployment and value extraction (Source: IT Voice).
# - **Government Support**: The IndiaAI Mission, with a budget of ₹10,371.92 crore, aims to promote AI development and adoption (Source: Mint).
# - **Workforce Challenges**: A significant skills gap exists, with demand for AI professionals exceeding supply, complicating implementation efforts (Source: India Today).
# - **Global Comparison**: Indian organizations are adopting AI technologies faster than many global counterparts, indicating a competitive edge (Source: Nature).
#
# ## 3. Financial Performance Analysis
# The financial performance of the Indian IT sector in 2026 reflects a complex landscape:
# - **Revenue Growth**: Major IT firms are expected to report modest growth, with estimates ranging from 0.2% to 1.7% for Q3 FY26. This is indicative of a broader trend of cautious spending by clients amid economic uncertainties (Source: Business Standard).
# - **Market Size**: The sector is on track to achieve a market size of USD 350 billion, driven by increasing demand for IT services and digital solutions (Source: McKinsey).
# - **Profit Margins**: Despite muted revenue growth, profit margins are expected to remain resilient, suggesting effective cost management strategies among leading firms (Source: Whalesbook).
#
# ## 4. Market Trends & Outlook
# - **AI Integration**: The adoption of AI technologies is becoming a cornerstone for IT firms, with applications ranging from automation in customer service to predictive analytics in supply chain management (Source: Webority).
# - **Government Initiatives**: The IndiaAI Mission and other government policies are fostering an environment conducive to AI innovation, with a focus on ethical AI and data governance (Source: PIB).
# - **Sectoral Growth**: Key sectors driving IT growth include healthcare, finance, and manufacturing, where AI is being leveraged to enhance operational efficiency and customer engagement (Source: EY).
#
# ## 5. Risks & Challenges
# - **Skills Gap**: The shortage of skilled AI professionals poses a significant barrier to effective implementation, with many firms struggling to find qualified candidates (Source: UMU).
# - **Infrastructure Limitations**: Inadequate digital infrastructure in certain regions may hinder the widespread adoption of AI technologies (Source: India Today).
# - **Regulatory Concerns**: Evolving regulations around data privacy and AI ethics could impact the pace of AI integration, necessitating compliance and adaptation by IT firms (Source: Economic Times).
#
# ## 6. Conclusion
# The Indian IT sector is poised for significant growth, driven by the increasing adoption of AI technologies and supportive government initiatives. However, firms must navigate challenges related to workforce skills and infrastructure to fully capitalize on these opportunities. As the sector evolves, strategic investments in talent development and technology infrastructure will be crucial for maintaining competitive advantage and achieving long-term growth.
# ============================================================
#
# 💾 Report saved to: outputs\reports\20260202_170746_Analyze_Indian_IT_sector_performance_and_AI_adopti.md
#
# 🎉 RESEARCH COMPLETE!
#    Report saved: outputs\reports\20260202_170746_Analyze_Indian_IT_sector_performance_and_AI_adopti.md

# %%
y
